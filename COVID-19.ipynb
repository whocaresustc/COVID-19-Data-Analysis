# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# Make multi-outputs in one cell:
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

pd.set_option('display.max_columns', 999)
pd.set_option('display.max_rows', 999)


import cufflinks
from plotly.offline import iplot, init_notebook_mode
# Using plotly + cufflinks in offline mode
import cufflinks
cufflinks.go_offline(connected=True)
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
submission = pd.read_csv("Data/covid19-global-forecasting-week-2/submission.csv")

# %%
test = pd.read_csv("Data/covid19-global-forecasting-week-2/test.csv")
#test.head(100)

# %%
#train.head(100)

# %%
train = pd.read_csv("Data/covid19-global-forecasting-week-2/train.csv")

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18816 entries, 0 to 18815
# Data columns (total 6 columns):
# Id                18816 non-null int64
# Country_Region    18816 non-null object
# Province_State    8000 non-null object
# Date              18816 non-null object
# ConfirmedCases    18816 non-null float64
# Fatalities        18816 non-null float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 882.1+ KB

# %%
train.head()
# Out:
#    Id Country_Region Province_State        Date  ConfirmedCases  Fatalities
# 0   1    Afghanistan            NaN  2020-01-22             0.0         0.0
# 1   2    Afghanistan            NaN  2020-01-23             0.0         0.0
# 2   3    Afghanistan            NaN  2020-01-24             0.0         0.0
# 3   4    Afghanistan            NaN  2020-01-25             0.0         0.0
# 4   5    Afghanistan            NaN  2020-01-26             0.0         0.0

# %%
train_grouped = train.groupby(['Country_Region'])

# %%
#train_grouped.get_group("Afghanistan")

# %%
#train_grouped.first() # first item in each group

# %%
China = train_grouped.get_group("China")

# %%
# columns needs to be categorical feature and value is continuous feature
train.pivot(columns='Country_Region', values='ConfirmedCases').iplot(
        kind='box',
        yTitle='Confirmed Cases',
        title='Confimred Cases by Country')

# %%
China.iplot(
    x='Date',
    y='ConfirmedCases',
    categories='Province_State',
    xTitle='Date',
    yTitle='Confirmed Cases',
    title='Confirmed Cases vs Date')
# Out:
# <div>
#
#
#             <div id="22dcbe31-d877-43c5-b873-1ee16c817719" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("22dcbe31-d877-43c5-b873-1ee16c817719")) {
#                     Plotly.newPlot(
#                         '22dcbe31-d877-43c5-b873-1ee16c817719',
# ...

# %%
China
# Out:
#       ConfirmedCases        Date  Fatalities    Id Province_State
# 3136             1.0  2020-01-22         0.0  4901          Anhui
# 3137             9.0  2020-01-23         0.0  4902          Anhui
# 3138            15.0  2020-01-24         0.0  4903          Anhui
# 3139            39.0  2020-01-25         0.0  4904          Anhui
# 3140            60.0  2020-01-26         0.0  4905          Anhui
# 3141            70.0  2020-01-27         0.0  4906          Anhui
# 3142           106.0  2020-01-28         0.0  4907          Anhui
# 3143           152.0  2020-01-29         0.0  4908          Anhui
# 3144           200.0  2020-01-30         0.0  4909          Anhui
# 3145           237.0  2020-01-31         0.0  4910          Anhui
# 3146           297.0  2020-02-01         0.0  4911          Anhui
# 3147           340.0  2020-02-02         0.0  4912          Anhui
# 3148           408.0  2020-02-03         0.0  4913          Anhui
# ...

# %%
China.shape
# Out:
# (2112, 5)
